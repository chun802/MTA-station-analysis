# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import savefig
import time


# %matplotlib inline

# %%
#to generate the date list for data download
date1 = '2017-09-23'   
date2 = '2018-09-22'
start = datetime.datetime.strptime(date1, '%Y-%m-%d')
end = datetime.datetime.strptime(date2, '%Y-%m-%d')
step = datetime.timedelta(days = 7)

week_nums_datetime_format = []
while start <= end:
    week_nums_datetime_format.append(start.date())
    start += step
    
week_nums_string = [str(week_num) for week_num in week_nums_datetime_format]

week_nums = [int(week_num[2:4] + week_num[5:7] + week_num[8:]) for week_num in week_nums_string]
print (week_nums)
# Out:
# [170923, 170930, 171007, 171014, 171021, 171028, 171104, 171111, 171118, 171125, 171202, 171209, 171216, 171223, 171230, 180106, 180113, 180120, 180127, 180203, 180210, 180217, 180224, 180303, 180310, 180317, 180324, 180331, 180407, 180414, 180421, 180428, 180505, 180512, 180519, 180526, 180602, 180609, 180616, 180623, 180630, 180707, 180714, 180721, 180728, 180804, 180811, 180818, 180825, 180901, 180908, 180915, 180922]

# %%
# Source: http://web.mta.info/developers/turnstile.html
#combine the data through the entire year to find a maximum 
def get_data(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    for week_num in week_nums:
        print (week_num)
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)
        
turnstiles_df = get_data(week_nums)
# Out:
# 170923
# 170930
# 171007
# 171014
# 171021
# 171028
# 171104
# 171111
# 171118
# 171125
# 171202
# 171209
# 171216
# 171223
# 171230
# 180106
# 180113
# 180120
# 180127
# 180203
# 180210
# 180217
# 180224
# 180303
# 180310
# 180317
# 180324
# 180331
# 180407
# 180414
# 180421
# 180428
# 180505
# 180512
# 180519
# 180526
# 180602
# 180609
# 180616
# 180623
# 180630
# 180707
# 180714
# 180721
# 180728
# 180804
# 180811
# 180818
# 180825
# 180901
# 180908
# 180915
# 180922

# %%
df = turnstiles_df.copy()

# %%
#generate a datetime object
df["DATE_TIME"] = pd.to_datetime(df.DATE + " " + df.TIME, format="%m/%d/%Y %H:%M:%S")

# %%
# to clean up the column formate
df.rename(columns={'ENTRIES': 'cumulative_entries', 'EXITS                                                               ': 'cumulative_exits'}, inplace=True)
# or use strip to clean the space
#turnstiles_df.columns = [column.strip() for column in turnstiles_df.columns

# %%
#first step to sort the values so the data is more organized and clear to process, expecially we will use diff to get
#difference between time points to get net entries or exits
df.sort_values(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True)

# %%
df.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  12:00:00
#
#       DESC  cumulative_entries  cumulative_exits           DATE_TIME
# 0  REGULAR             6328434           2141537 2017-09-16 00:00:00
# 1  REGULAR             6328480           2141541 2017-09-16 04:00:00
# 2  REGULAR             6328503           2141580 2017-09-16 08:00:00
# 3  REGULAR             6328598           2141674 2017-09-16 12:00:00
# 4  REGULAR             6328838           2141731 2017-09-16 16:00:00
# 5  REGULAR             6329154           2141779 2017-09-16 20:00:00
# 6  REGULAR             6329336           2141799 2017-09-17 00:00:00
# 7  REGULAR             6329364           2141801 2017-09-17 04:00:00
# 8  REGULAR             6329382           2141821 2017-09-17 08:00:00
# 9  REGULAR             6329451           2141887 2017-09-17 12:00:00

# %%
# one turnstile--identified by C/A, UNIT, SCP at one specific station at one specific time should be unique, check
# to make sure
(df
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
 .cumulative_entries.count()
 .reset_index()
 .sort_values("cumulative_entries", ascending=False)).head(20)
# Out:
#            C/A  UNIT       SCP          STATION           DATE_TIME  \
# 1144163   C014  R246  00-00-00      PROSPECT AV 2017-10-29 16:00:00
# 471238    A050  R088  00-02-00     CORTLANDT ST 2017-12-28 20:00:00
# 576922    A061  R142  00-00-00   DELANCEY/ESSEX 2017-10-27 09:00:00
# 1144160   C014  R246  00-00-00      PROSPECT AV 2017-10-29 04:00:00
# 1144161   C014  R246  00-00-00      PROSPECT AV 2017-10-29 08:00:00
# 1144162   C014  R246  00-00-00      PROSPECT AV 2017-10-29 12:00:00
# 9419570   R515  R095  00-00-01  ASTORIA DITMARS 2018-08-07 16:00:00
# 1144164   C014  R246  00-00-00      PROSPECT AV 2017-10-29 20:00:00
# 1144165   C014  R246  00-00-00      PROSPECT AV 2017-10-30 00:00:00
# 10166515  R627  R063  00-03-02  SUTTER AV-RUTLD 2018-02-04 07:00:00
# 1144166   C014  R246  00-00-00      PROSPECT AV 2017-10-30 04:00:00
# 1144167   C014  R246  00-00-00      PROSPECT AV 2017-10-30 08:00:00
# 1144168   C014  R246  00-00-00      PROSPECT AV 2017-10-30 12:00:00
# 1144169   C014  R246  00-00-00      PROSPECT AV 2017-10-30 16:00:00
# 1144170   C014  R246  00-00-00      PROSPECT AV 2017-10-30 20:00:00
# 2743647   N071  R013  00-00-01   34 ST-PENN STA 2018-01-04 15:00:00
# 1144176   C014  R246  00-00-00      PROSPECT AV 2017-10-31 20:00:00
# 6876128   R135  R031  01-00-00   34 ST-PENN STA 2018-03-22 08:00:00
# 471242    A050  R088  00-02-00     CORTLANDT ST 2017-12-29 00:00:00
# 1144177   C014  R246  00-00-00      PROSPECT AV 2017-11-01 00:00:00
#
#           cumulative_entries
# 1144163                    2
# 471238                     2
# 576922                     2
# 1144160                    2
# 1144161                    2
# 1144162                    2
# 9419570                    2
# 1144164                    2
# 1144165                    2
# 10166515                   2
# 1144166                    2
# 1144167                    2
# 1144168                    2
# 1144169                    2
# 1144170                    2
# 2743647                    2
# 1144176                    2
# 6876128                    2
# 471242                     2
# 1144177                    2

# %%
df['DATE_TIME'].describe()
# Out:
# count                10476883
# unique                 686597
# top       2018-03-03 23:00:00
# freq                     2444
# first     2017-09-16 00:00:00
# last      2018-09-21 23:59:34
# Name: DATE_TIME, dtype: object

# %%
from datetime import datetime

# %%
#take a look at at the specific time and station to see why there is 2 values
mask = ((df['C/A'] == 'C014') &
        (df['UNIT'] == 'R246') &
        (df['SCP'] == '00-00-00')&
        (df['STATION'] == 'PROSPECT AV')&
        (df['DATE_TIME'] == datetime(*(2017, 10, 29, 16, 0, 0))))

df[mask]
# Out:
#         C/A  UNIT       SCP      STATION LINENAME DIVISION        DATE  \
# 21412  C014  R246  00-00-00  PROSPECT AV        R      BMT  10/29/2017
# 21413  C014  R246  00-00-00  PROSPECT AV        R      BMT  10/29/2017
#
#            TIME        DESC  cumulative_entries  cumulative_exits  \
# 21412  16:00:00     REGULAR            12366621           2707166
# 21413  16:00:00  RECOVR AUD             8239903           3204411
#
#                 DATE_TIME
# 21412 2017-10-29 16:00:00
# 21413 2017-10-29 16:00:00

# %%
# there is a regular and a recor aud values, drop the recovr aud values. It is good practice to check whether there is 
# unexpected different values assign to one specific indentifier
df.drop_duplicates(subset=["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True)

# %%
# shift the data down one row so can get the previous time point number
df[['pre_CA','preUNIT','pre_SCP','pre_date','pre_entries','pre_exits']] = (df[['C/A','UNIT','SCP','DATE_TIME','cumulative_entries','cumulative_exits']].transform(lambda grp: grp.shift(1)))

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  16:00:00
#
#       DESC  cumulative_entries  cumulative_exits           DATE_TIME pre_CA  \
# 0  REGULAR             6328434           2141537 2017-09-16 00:00:00    NaN
# 1  REGULAR             6328480           2141541 2017-09-16 04:00:00   A002
# 2  REGULAR             6328503           2141580 2017-09-16 08:00:00   A002
# 3  REGULAR             6328598           2141674 2017-09-16 12:00:00   A002
# 4  REGULAR             6328838           2141731 2017-09-16 16:00:00   A002
#
#   preUNIT   pre_SCP            pre_date  pre_entries  pre_exits
# 0     NaN       NaN                 NaT          NaN        NaN
# 1    R051  02-00-00 2017-09-16 00:00:00    6328434.0  2141537.0
# 2    R051  02-00-00 2017-09-16 04:00:00    6328480.0  2141541.0
# 3    R051  02-00-00 2017-09-16 08:00:00    6328503.0  2141580.0
# 4    R051  02-00-00 2017-09-16 12:00:00    6328598.0  2141674.0

# %%
#create the turnstile_id for the current turnstile

df['Turnstile_id'] = df['C/A'] + ' ' + df['UNIT'] + df['SCP']

# %%
#create the turnstile_id for the previous turnstile

df['pre_Turnstile_id'] = df['pre_CA'] + ' ' + df['preUNIT'] + df['pre_SCP']

# %%
df.head(5)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  16:00:00
#
#       DESC  cumulative_entries  cumulative_exits           DATE_TIME pre_CA  \
# 0  REGULAR             6328434           2141537 2017-09-16 00:00:00    NaN
# 1  REGULAR             6328480           2141541 2017-09-16 04:00:00   A002
# 2  REGULAR             6328503           2141580 2017-09-16 08:00:00   A002
# 3  REGULAR             6328598           2141674 2017-09-16 12:00:00   A002
# 4  REGULAR             6328838           2141731 2017-09-16 16:00:00   A002
#
#   preUNIT   pre_SCP            pre_date  pre_entries  pre_exits  \
# 0     NaN       NaN                 NaT          NaN        NaN
# 1    R051  02-00-00 2017-09-16 00:00:00    6328434.0  2141537.0
# 2    R051  02-00-00 2017-09-16 04:00:00    6328480.0  2141541.0
# 3    R051  02-00-00 2017-09-16 08:00:00    6328503.0  2141580.0
# 4    R051  02-00-00 2017-09-16 12:00:00    6328598.0  2141674.0
#
#         Turnstile_id   pre_Turnstile_id
# 0  A002 R05102-00-00                NaN
# 1  A002 R05102-00-00  A002 R05102-00-00
# 2  A002 R05102-00-00  A002 R05102-00-00
# 3  A002 R05102-00-00  A002 R05102-00-00
# 4  A002 R05102-00-00  A002 R05102-00-00

# %%
#filter the data to have only the turstile_id mathching with the previous time piont, otherwise it will substract between two
#turstile, and the number is meaningless

df1 = df[df['Turnstile_id'] == df['pre_Turnstile_id']].copy()

# %%
df1.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  20:00:00
#
#       DESC  cumulative_entries  cumulative_exits           DATE_TIME pre_CA  \
# 1  REGULAR             6328480           2141541 2017-09-16 04:00:00   A002
# 2  REGULAR             6328503           2141580 2017-09-16 08:00:00   A002
# 3  REGULAR             6328598           2141674 2017-09-16 12:00:00   A002
# 4  REGULAR             6328838           2141731 2017-09-16 16:00:00   A002
# 5  REGULAR             6329154           2141779 2017-09-16 20:00:00   A002
#
#   preUNIT   pre_SCP            pre_date  pre_entries  pre_exits  \
# 1    R051  02-00-00 2017-09-16 00:00:00    6328434.0  2141537.0
# 2    R051  02-00-00 2017-09-16 04:00:00    6328480.0  2141541.0
# 3    R051  02-00-00 2017-09-16 08:00:00    6328503.0  2141580.0
# 4    R051  02-00-00 2017-09-16 12:00:00    6328598.0  2141674.0
# 5    R051  02-00-00 2017-09-16 16:00:00    6328838.0  2141731.0
#
#         Turnstile_id   pre_Turnstile_id
# 1  A002 R05102-00-00  A002 R05102-00-00
# 2  A002 R05102-00-00  A002 R05102-00-00
# 3  A002 R05102-00-00  A002 R05102-00-00
# 4  A002 R05102-00-00  A002 R05102-00-00
# 5  A002 R05102-00-00  A002 R05102-00-00

# %%
#calculate net_entries and net_exits based on the current and previous data point
#create a column net_traffic for the total traffic
#also create a column records the time span, since there is different way how time was recorded, the time span might be 
#different

df1['net_entries'] = df1['cumulative_entries'] - df1['pre_entries']
df1['net_exits'] = df1['cumulative_exits'] - df1['pre_exits']
df1['net_traffic'] = df1['net_entries'] + df1['net_exits']
df1['time_span_min'] = (df1['DATE_TIME'] - df1['pre_date']).dt.seconds/60
df1['time_span_hour'] =  (df1['DATE_TIME'] - df1['pre_date']).dt.seconds/60/60

# %%
df1.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  20:00:00
#
#       DESC  cumulative_entries      ...                  pre_date pre_entries  \
# 1  REGULAR             6328480      ...       2017-09-16 00:00:00   6328434.0
# 2  REGULAR             6328503      ...       2017-09-16 04:00:00   6328480.0
# 3  REGULAR             6328598      ...       2017-09-16 08:00:00   6328503.0
# 4  REGULAR             6328838      ...       2017-09-16 12:00:00   6328598.0
# 5  REGULAR             6329154      ...       2017-09-16 16:00:00   6328838.0
#
#    pre_exits       Turnstile_id   pre_Turnstile_id net_entries  net_exits  \
# 1  2141537.0  A002 R05102-00-00  A002 R05102-00-00        46.0        4.0
# 2  2141541.0  A002 R05102-00-00  A002 R05102-00-00        23.0       39.0
# 3  2141580.0  A002 R05102-00-00  A002 R05102-00-00        95.0       94.0
# 4  2141674.0  A002 R05102-00-00  A002 R05102-00-00       240.0       57.0
# 5  2141731.0  A002 R05102-00-00  A002 R05102-00-00       316.0       48.0
#
#    net_traffic time_span_min time_span_hour
# 1         50.0         240.0            4.0
# 2         62.0         240.0            4.0
# 3        189.0         240.0            4.0
# 4        297.0         240.0            4.0
# 5        364.0         240.0            4.0
#
# [5 rows x 25 columns]

# %%
#check the different time span
(df1.groupby('time_span_hour').count().reset_index()).head(20)
# Out:
#     time_span_hour  C/A  UNIT  SCP  STATION  LINENAME  DIVISION  DATE  TIME  \
# 0         0.000000  245   245  245      245       245       245   245   245
# 1         0.000278   38    38   38       38        38        38    38    38
# 2         0.000556   57    57   57       57        57        57    57    57
# 3         0.000833   13    13   13       13        13        13    13    13
# 4         0.001111    2     2    2        2         2         2     2     2
# 5         0.001389   23    23   23       23        23        23    23    23
# 6         0.001667   18    18   18       18        18        18    18    18
# 7         0.001944   19    19   19       19        19        19    19    19
# 8         0.002222    7     7    7        7         7         7     7     7
# 9         0.002500   24    24   24       24        24        24    24    24
# 10        0.002778   19    19   19       19        19        19    19    19
# 11        0.003056   40    40   40       40        40        40    40    40
# 12        0.003333   13    13   13       13        13        13    13    13
# 13        0.003611   16    16   16       16        16        16    16    16
# 14        0.003889    4     4    4        4         4         4     4     4
# 15        0.004167   44    44   44       44        44        44    44    44
# 16        0.004444   40    40   40       40        40        40    40    40
# 17        0.004722   18    18   18       18        18        18    18    18
# 18        0.005000   58    58   58       58        58        58    58    58
# 19        0.005278   26    26   26       26        26        26    26    26
#
#     DESC      ...        pre_SCP  pre_date  pre_entries  pre_exits  \
# 0    245      ...            245       245          245        245
# 1     38      ...             38        38           38         38
# 2     57      ...             57        57           57         57
# 3     13      ...             13        13           13         13
# 4      2      ...              2         2            2          2
# 5     23      ...             23        23           23         23
# 6     18      ...             18        18           18         18
# 7     19      ...             19        19           19         19
# 8      7      ...              7         7            7          7
# 9     24      ...             24        24           24         24
# 10    19      ...             19        19           19         19
# 11    40      ...             40        40           40         40
# 12    13      ...             13        13           13         13
# 13    16      ...             16        16           16         16
# 14     4      ...              4         4            4          4
# 15    44      ...             44        44           44         44
# 16    40      ...             40        40           40         40
# 17    18      ...             18        18           18         18
# 18    58      ...             58        58           58         58
# 19    26      ...             26        26           26         26
#
#     Turnstile_id  pre_Turnstile_id  net_entries  net_exits  net_traffic  \
# 0            245               245          245        245          245
# 1             38                38           38         38           38
# 2             57                57           57         57           57
# 3             13                13           13         13           13
# 4              2                 2            2          2            2
# 5             23                23           23         23           23
# 6             18                18           18         18           18
# 7             19                19           19         19           19
# 8              7                 7            7          7            7
# 9             24                24           24         24           24
# 10            19                19           19         19           19
# 11            40                40           40         40           40
# 12            13                13           13         13           13
# 13            16                16           16         16           16
# 14             4                 4            4          4            4
# 15            44                44           44         44           44
# 16            40                40           40         40           40
# 17            18                18           18         18           18
# 18            58                58           58         58           58
# 19            26                26           26         26           26
#
#     time_span_min
# 0             245
# 1              38
# 2              57
# 3              13
# 4               2
# 5              23
# 6              18
# 7              19
# 8               7
# 9              24
# 10             19
# 11             40
# 12             13
# 13             16
# 14              4
# 15             44
# 16             40
# 17             18
# 18             58
# 19             26
#
# [20 rows x 25 columns]

# %%
#there is lots of time span is very short, filter those out, I specfically take a 4-hour time slot
df2 = df1.copy()
df2 = df2[df2['time_span_hour']  == 4]

# %%
#to look at what kind of time span and how frequent they are
(df2.groupby('time_span_hour').count().reset_index().sort_values("time_span_min", ascending=False)).head(30)
# Out:
#    time_span_hour      C/A     UNIT      SCP  STATION  LINENAME  DIVISION  \
# 0             4.0  9626769  9626769  9626769  9626769   9626769   9626769
#
#       DATE     TIME     DESC      ...        pre_SCP  pre_date  pre_entries  \
# 0  9626769  9626769  9626769      ...        9626769   9626769      9626769
#
#    pre_exits  Turnstile_id  pre_Turnstile_id  net_entries  net_exits  \
# 0    9626769       9626769           9626769      9626769    9626769
#
#    net_traffic  time_span_min
# 0      9626769        9626769
#
# [1 rows x 25 columns]

# %%
#clean up the n/a data
df2.dropna(how = 'any').copy().head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  20:00:00
#
#       DESC  cumulative_entries      ...                  pre_date pre_entries  \
# 1  REGULAR             6328480      ...       2017-09-16 00:00:00   6328434.0
# 2  REGULAR             6328503      ...       2017-09-16 04:00:00   6328480.0
# 3  REGULAR             6328598      ...       2017-09-16 08:00:00   6328503.0
# 4  REGULAR             6328838      ...       2017-09-16 12:00:00   6328598.0
# 5  REGULAR             6329154      ...       2017-09-16 16:00:00   6328838.0
#
#    pre_exits       Turnstile_id   pre_Turnstile_id net_entries  net_exits  \
# 1  2141537.0  A002 R05102-00-00  A002 R05102-00-00        46.0        4.0
# 2  2141541.0  A002 R05102-00-00  A002 R05102-00-00        23.0       39.0
# 3  2141580.0  A002 R05102-00-00  A002 R05102-00-00        95.0       94.0
# 4  2141674.0  A002 R05102-00-00  A002 R05102-00-00       240.0       57.0
# 5  2141731.0  A002 R05102-00-00  A002 R05102-00-00       316.0       48.0
#
#    net_traffic time_span_min time_span_hour
# 1         50.0         240.0            4.0
# 2         62.0         240.0            4.0
# 3        189.0         240.0            4.0
# 4        297.0         240.0            4.0
# 5        364.0         240.0            4.0
#
# [5 rows x 25 columns]

# %%
#take a look at the range of net_entries data
df2.net_entries.describe()
# Out:
# count    9.626769e+06
# mean     1.270700e+03
# std      2.465189e+06
# min     -2.142302e+09
# 25%      1.100000e+01
# 50%      7.600000e+01
# 75%      2.410000e+02
# max      2.142302e+09
# Name: net_entries, dtype: float64

# %%
#there is some abnormally low and high number. For the negative number, it might due to turstile reset, filter those out
df3 = df2[(df2['net_entries']>0) & (df2['net_exits']>0)].copy()

# %%
#take a look again 
df3.net_entries.describe()
# Out:
# count    7.929183e+06
# mean     3.481443e+03
# std      2.153976e+06
# min      1.000000e+00
# 25%      3.400000e+01
# 50%      1.180000e+02
# 75%      2.890000e+02
# max      2.142302e+09
# Name: net_entries, dtype: float64

# %%
df3.net_exits.describe()
# Out:
# count    7.929183e+06
# mean     4.259109e+03
# std      2.592156e+06
# min      1.000000e+00
# 25%      2.600000e+01
# 50%      7.800000e+01
# 75%      1.970000e+02
# max      2.145033e+09
# Name: net_exits, dtype: float64

# %%
#there is some really high number in both columns, which is impossbile. This is only one turstile during 4 hours, 
#thinking that even one entries per second, it will only be 4* 3600 per turstile, take a look at the abnormal number
df_high_entries = df3[df3.net_entries > 50000]
df_high_entries[['STATION','DATE_TIME','cumulative_entries','Turnstile_id','pre_date','pre_entries','pre_Turnstile_id','net_entries','DESC']].head(20)
# Out:
#                STATION           DATE_TIME  cumulative_entries  \
# 12755        FULTON ST 2018-02-15 10:00:00           101515533
# 14947     CORTELYOU RD 2018-09-15 00:00:00            15832652
# 15402         AVENUE H 2018-05-23 16:00:00              616630
# 22769            53 ST 2018-08-14 12:00:00            50386730
# 23018     BAY RIDGE AV 2017-10-10 20:00:00             5184970
# 23088     BAY RIDGE AV 2017-10-11 16:00:00             7595915
# 28633  CONEY IS-STILLW 2018-03-31 17:00:00             1900568
# 41724           190 ST 2018-06-10 20:00:00          1442830408
# 48842  42 ST-PORT AUTH 2017-10-17 12:00:00              262144
# 50099  42 ST-PORT AUTH 2018-01-05 13:00:00            68254430

# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  16:00:00
#
#        DESC  cumulative_entries      ...                  pre_date  \
# 1   REGULAR             6328480      ...       2017-09-16 00:00:00
# 2   REGULAR             6328503      ...       2017-09-16 04:00:00
# 3   REGULAR             6328598      ...       2017-09-16 08:00:00
# 4   REGULAR             6328838      ...       2017-09-16 12:00:00
# 5   REGULAR             6329154      ...       2017-09-16 16:00:00
# 6   REGULAR             6329336      ...       2017-09-16 20:00:00
# 7   REGULAR             6329364      ...       2017-09-17 00:00:00
# 8   REGULAR             6329382      ...       2017-09-17 04:00:00
# 9   REGULAR             6329451      ...       2017-09-17 08:00:00
# 10  REGULAR             6329655      ...       2017-09-17 12:00:00
#
#    pre_entries  pre_exits       Turnstile_id   pre_Turnstile_id net_entries  \
# 1    6328434.0  2141537.0  A002 R05102-00-00  A002 R05102-00-00        46.0
# 2    6328480.0  2141541.0  A002 R05102-00-00  A002 R05102-00-00        23.0
# 3    6328503.0  2141580.0  A002 R05102-00-00  A002 R05102-00-00        95.0
# 4    6328598.0  2141674.0  A002 R05102-00-00  A002 R05102-00-00       240.0
# 5    6328838.0  2141731.0  A002 R05102-00-00  A002 R05102-00-00       316.0
# 6    6329154.0  2141779.0  A002 R05102-00-00  A002 R05102-00-00       182.0
# 7    6329336.0  2141799.0  A002 R05102-00-00  A002 R05102-00-00        28.0
# 8    6329364.0  2141801.0  A002 R05102-00-00  A002 R05102-00-00        18.0
# 9    6329382.0  2141821.0  A002 R05102-00-00  A002 R05102-00-00        69.0
# 10   6329451.0  2141887.0  A002 R05102-00-00  A002 R05102-00-00       204.0
#
#     net_exits  net_traffic time_span_min time_span_hour
# 1         4.0         50.0         240.0            4.0
# 2        39.0         62.0         240.0            4.0
# 3        94.0        189.0         240.0            4.0
# 4        57.0        297.0         240.0            4.0
# 5        48.0        364.0         240.0            4.0
# 6        20.0        202.0         240.0            4.0
# 7         2.0         30.0         240.0            4.0
# 8        20.0         38.0         240.0            4.0
# 9        66.0        135.0         240.0            4.0
# 10       54.0        258.0         240.0            4.0
#
# [10 rows x 25 columns]

# %%
#still don't know what happened to those really big numbers, but they are simply impossible, filter those out
#I chose 30,000 to be the upper limit for each turstile during 4 hour time frame, assumming people passing through that 
#turnstile non_stop
df_filter_exits_entries = df3[(df3['net_entries']<30000) &(df3['net_exits']<30000)]

# %%
df_filter_exits_entries.net_entries.describe()
df_filter_exits_entries.net_entries.describe()
# Out:
# count    7.929123e+06
# mean     2.116906e+02
# std      2.650638e+02
# min      1.000000e+00
# 25%      3.400000e+01
# 50%      1.180000e+02
# 75%      2.890000e+02
# max      1.129400e+04
# Name: net_entries, dtype: float64

# %%
#after filter data looks more resonable
df_filter_exits_entries.head(10)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2017  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/17/2017  16:00:00
#
#        DESC  cumulative_entries      ...                  pre_date  \
# 1   REGULAR             6328480      ...       2017-09-16 00:00:00
# 2   REGULAR             6328503      ...       2017-09-16 04:00:00
# 3   REGULAR             6328598      ...       2017-09-16 08:00:00
# 4   REGULAR             6328838      ...       2017-09-16 12:00:00
# 5   REGULAR             6329154      ...       2017-09-16 16:00:00
# 6   REGULAR             6329336      ...       2017-09-16 20:00:00
# 7   REGULAR             6329364      ...       2017-09-17 00:00:00
# 8   REGULAR             6329382      ...       2017-09-17 04:00:00
# 9   REGULAR             6329451      ...       2017-09-17 08:00:00
# 10  REGULAR             6329655      ...       2017-09-17 12:00:00
#
#    pre_entries  pre_exits       Turnstile_id   pre_Turnstile_id net_entries  \
# 1    6328434.0  2141537.0  A002 R05102-00-00  A002 R05102-00-00        46.0
# 2    6328480.0  2141541.0  A002 R05102-00-00  A002 R05102-00-00        23.0
# 3    6328503.0  2141580.0  A002 R05102-00-00  A002 R05102-00-00        95.0
# 4    6328598.0  2141674.0  A002 R05102-00-00  A002 R05102-00-00       240.0
# 5    6328838.0  2141731.0  A002 R05102-00-00  A002 R05102-00-00       316.0
# 6    6329154.0  2141779.0  A002 R05102-00-00  A002 R05102-00-00       182.0
# 7    6329336.0  2141799.0  A002 R05102-00-00  A002 R05102-00-00        28.0
# 8    6329364.0  2141801.0  A002 R05102-00-00  A002 R05102-00-00        18.0
# 9    6329382.0  2141821.0  A002 R05102-00-00  A002 R05102-00-00        69.0
# 10   6329451.0  2141887.0  A002 R05102-00-00  A002 R05102-00-00       204.0
#
#     net_exits  net_traffic time_span_min time_span_hour
# 1         4.0         50.0         240.0            4.0
# 2        39.0         62.0         240.0            4.0
# 3        94.0        189.0         240.0            4.0
# 4        57.0        297.0         240.0            4.0
# 5        48.0        364.0         240.0            4.0
# 6        20.0        202.0         240.0            4.0
# 7         2.0         30.0         240.0            4.0
# 8        20.0         38.0         240.0            4.0
# 9        66.0        135.0         240.0            4.0
# 10       54.0        258.0         240.0            4.0
#
# [10 rows x 25 columns]

# %%
#another look at the net_traffic
df_filter_exits_entries.net_traffic.describe()
# Out:
# count    7.929123e+06
# mean     3.715133e+02
# std      3.946991e+02
# min      2.000000e+00
# 25%      8.600000e+01
# 50%      2.440000e+02
# 75%      5.240000e+02
# max      1.833300e+04
# Name: net_traffic, dtype: float64

# %%
#get the total counts by stations during the 4 hour time frame
df6 = df_filter_exits_entries.groupby(['STATION','DATE_TIME']).sum().reset_index().copy()

# %%
df6.head(20)
# Out:
#    STATION           DATE_TIME  cumulative_entries  cumulative_exits  \
# 0     1 AV 2017-09-16 04:00:00          3040842809        1640287259
# 1     1 AV 2017-09-16 08:00:00          3040843356        1640288217
# 2     1 AV 2017-09-16 12:00:00          3040845907        1640291119
# 3     1 AV 2017-09-16 16:00:00          3040850403        1640295482
# 4     1 AV 2017-09-16 20:00:00          3040855163        1640300794
# 5     1 AV 2017-09-17 00:00:00          3040859156        1640305002
# 6     1 AV 2017-09-17 04:00:00          3040860741        1640306259
# 7     1 AV 2017-09-17 08:00:00          3040861196        1640306919
# 8     1 AV 2017-09-17 12:00:00          3040863253        1640309140
# 9     1 AV 2017-09-17 16:00:00          3028144160        1626198652
# 6    1 AV 2017-09-17 04:00:00       2842.0
# 7    1 AV 2017-09-17 08:00:00       1115.0
# 8    1 AV 2017-09-17 12:00:00       4278.0
# 9    1 AV 2017-09-17 16:00:00       5981.0

# %%
#sort values by the total net_traffic
df7.sort_values(by = 'net_traffic', inplace = True, ascending=False)

# %%
# generate the top 20 list
df7.head(20)
# Out:
#                 STATION           DATE_TIME  net_traffic
# 150925   34 ST-PENN STA 2017-11-07 19:00:00      89564.0
# 146422  34 ST-HERALD SQ 2017-12-08 19:00:00      88993.0
# 146464  34 ST-HERALD SQ 2017-12-15 19:00:00      88973.0
# 146488  34 ST-HERALD SQ 2017-12-19 19:00:00      88161.0
# 146494  34 ST-HERALD SQ 2017-12-20 19:00:00      88046.0
# 151381   34 ST-PENN STA 2017-12-15 19:00:00      86778.0
# 147129  34 ST-HERALD SQ 2018-04-05 20:00:00      86455.0
# 146380  34 ST-HERALD SQ 2017-12-01 19:00:00      85679.0
# 146500  34 ST-HERALD SQ 2017-12-21 19:00:00      85656.0
# 153189   34 ST-PENN STA 2018-05-15 20:00:00      85427.0
# 154629   34 ST-PENN STA 2018-09-12 20:00:00      85289.0
# 151297   34 ST-PENN STA 2017-12-08 19:00:00      85135.0
# 146236  34 ST-HERALD SQ 2017-11-07 19:00:00      84977.0
# 148137  34 ST-HERALD SQ 2018-09-20 20:00:00      84857.0
# 147801  34 ST-HERALD SQ 2018-07-26 20:00:00      84765.0
# 153945   34 ST-PENN STA 2018-07-17 20:00:00      84618.0
# 150867   34 ST-PENN STA 2017-11-02 20:00:00      84402.0
# 147009  34 ST-HERALD SQ 2018-03-16 20:00:00      84193.0
# 146171  34 ST-HERALD SQ 2017-10-27 20:00:00      84174.0
# 147123  34 ST-HERALD SQ 2018-04-04 20:00:00      83987.0

# %%
# to see what day of the week that is
df7['DATE_format'] = pd.to_datetime(df7['DATE_TIME'],format="%m/%d/%Y")
df7['weekday'] = df7['DATE_format'].dt.day_name()
df7['hour'] = df7['DATE_TIME'].apply(lambda x: x.hour)

# %%
df7.head(20)
# Out:
#                 STATION           DATE_TIME  net_traffic         DATE_format  \
# 150925   34 ST-PENN STA 2017-11-07 19:00:00      89564.0 2017-11-07 19:00:00
# 146422  34 ST-HERALD SQ 2017-12-08 19:00:00      88993.0 2017-12-08 19:00:00
# 146464  34 ST-HERALD SQ 2017-12-15 19:00:00      88973.0 2017-12-15 19:00:00
# 146488  34 ST-HERALD SQ 2017-12-19 19:00:00      88161.0 2017-12-19 19:00:00
# 146494  34 ST-HERALD SQ 2017-12-20 19:00:00      88046.0 2017-12-20 19:00:00
# 151381   34 ST-PENN STA 2017-12-15 19:00:00      86778.0 2017-12-15 19:00:00
# 147129  34 ST-HERALD SQ 2018-04-05 20:00:00      86455.0 2018-04-05 20:00:00
# 146380  34 ST-HERALD SQ 2017-12-01 19:00:00      85679.0 2017-12-01 19:00:00
# 146500  34 ST-HERALD SQ 2017-12-21 19:00:00      85656.0 2017-12-21 19:00:00
# 153189   34 ST-PENN STA 2018-05-15 20:00:00      85427.0 2018-05-15 20:00:00
# 147303  34 ST-HERALD SQ 2018-05-04 20:00:00      81058.0 2018-05-04 20:00:00
# 146296  34 ST-HERALD SQ 2017-11-17 19:00:00      80701.0 2017-11-17 19:00:00
# 146129  34 ST-HERALD SQ 2017-10-20 20:00:00      79794.0 2017-10-20 20:00:00
# 147261  34 ST-HERALD SQ 2018-04-27 20:00:00      79558.0 2018-04-27 20:00:00
# 146716  34 ST-HERALD SQ 2018-01-26 19:00:00      78559.0 2018-01-26 19:00:00
# 147135  34 ST-HERALD SQ 2018-04-06 20:00:00      78199.0 2018-04-06 20:00:00
# 146087  34 ST-HERALD SQ 2017-10-13 20:00:00      77690.0 2017-10-13 20:00:00
#
#        weekday  hour
# 146422  Friday    19
# 146464  Friday    19
# 146380  Friday    19
# 147009  Friday    20
# 146171  Friday    20
# 146213  Friday    20
# 147051  Friday    20
# 148143  Friday    20
# 147345  Friday    20
# 147219  Friday    20
# 148101  Friday    20
# 146968  Friday    19
# 146254  Friday    19
# 147303  Friday    20
# 146296  Friday    19
# 146129  Friday    20
# 147261  Friday    20
# 146716  Friday    19
# 147135  Friday    20
# 146087  Friday    20

# %%
herald_sq_friday_rush_hour.net_traffic.describe()
# Out:
# count       53.000000
# mean     75968.905660
# std       6444.680144
# min      59695.000000
# 25%      72285.000000
# 50%      76082.000000
# 75%      81058.000000
# max      88993.000000
# Name: net_traffic, dtype: float64

# %%
median_vs_max_df = pd.read_csv('34_st_hearld_friday_rush_hour.csv')
median_vs_max_df
# Out:
#    STATUS  Traffic
# 0  Median    76082
# 1     Max    88993

# %%
sns.set()

# %%
median_max_plot = sns.barplot(x="STATUS", y='Traffic', data=median_vs_max_df, palette=("colorblind"),label = None)
median_max_plot.set_xlabel("")
median_max_plot.set_ylabel('Traffic',size = 20)
# %config InlineBackend.figure_format = 'svg'

# %%
#compared it to the median number to make sure it is not a randomly, inaacurate high number
#it is about 12,000 people more on that day
#It turns out to be an event nearby

# %%
#My hypothesis is that if there is an event closeby, we will get a high number in a short period of time. 
#To test this hypothesis, we need to compare the high traffic with event lists.
#I noticed that the top 20 high numbers are in either 34 penn station or herald square, which are within 2 
#blocks away from madison square garden. So the initial quick check is to compare the event list of MSG with 
#the top 20 dates
#There is some hits: for example: on 2017-12-20, there is Billy Joel's concert; on 2017-12-8, there is a Jingle Ball 
#concert
#Next step is to analyze what event we should target.

# %%
import seaborn as sns
from pylab import savefig
sns.set(style="whitegrid")
Population_chart = sns.barplot(x="STATION", y="POPULATION", data=zipCodeData, palette=("colorblind"),label = None)
Population_chart.set_xticklabels(zipCodeData.STATION,rotation= 90)
Population_chart.set_xlabel("")
Population_chart.set_ylabel('POPULATION',size = 20)
Population_chart2 =Population_chart.twinx()
fig = zipCodeData.plot(x="STATION", y="NETTRAFFIC", ax=Population_chart2, legend=True, color="black",grid=False, linewidth = 5)

#%config InlineBackend.figure_format = 'jpeg'
figure = fig.get_figure()    
figure.savefig('polulation_station.jpeg', dpi= 3000, bbox_inches='tight')

#sns.set_context("poster")
#sns.set_context("poster", font_scale= 1)
